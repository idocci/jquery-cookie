# %% [markdown]
# <a href="https://colab.research.google.com/github/idocci/jquery-cookie/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio

# %%
pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 68.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...

# %%
import gradio as gr
from diffusers import StableDiffusionPipeline

model = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
def generate_banner(prompt):
    image = model(prompt).images[0]
    return image

demo = gr.Interface(fn=generate_banner, inputs="text", outputs="image")
demo.launch()

def generate_banner(prompt):
    image = model(prompt).images[0]
    return image

demo = gr.Interface(fn=generate_banner, inputs="text", outputs="image")
demo.launch()
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# ...

# %%
demo.launch(share=True)
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://acfec5399bc37787d0.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://acfec5399bc37787d0.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import torch
from diffusers import StableDiffusionPipeline
# GPUチェック
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# モデルロード（要ダウンロード）
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id).to(device)
# バナー生成関数
def generate_banner(prompt):
    image = pipe(prompt).images[0]
    return image
# Gradio UI
demo = gr.Interface(fn=generate_banner, inputs="text", outputs="image")
demo.launch(share=True)

# バナー生成関数 def generate_banner(prompt):
    image = pipe(prompt).images[0]
    return image
# Gradio UIdemo = gr.Interface(fn=generate_banner, inputs="text", outputs="image")
demo.launch(share=True)
# Out:
#   File "<ipython-input-9-ee49ed4f8319>", line 19
#     image = pipe(prompt).images[0]
#     ^
# IndentationError: unexpected indent

# %%
import gradio as gr
import torch
from diffusers import StableDiffusionPipeline
# GPUチェック
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# モデルロード（要ダウンロード）
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id).to(device)
# バナー生成関数
def generate_banner(prompt):
    image = pipe(prompt).images[0]
    return image
# Gradio UI
demo = gr.Interface(fn=generate_banner, inputs="text", outputs="image")
demo.launch(share=True)

# The following lines were causing the error due to incorrect indentation and incomplete code.
# They have been removed or corrected:
# バナー生成関数 def generate_banner(prompt):
#    image = pipe(prompt).images[0]
#    return image
# Gradio UIdemo = gr.Interface(fn=generate_banner, inputs="text", outputs="image")
# demo.launch(share=True)
# Out:
# Using device: cpu
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://381fb0bb5589390ad6.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://381fb0bb5589390ad6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")
# Out:
# CUDA available: False
# Device: CPU only

# %%
from diffusers import StableDiffusionPipeline

model_id = "runwayml/stable-diffusion-v1-5"
try:
    pipe = StableDiffusionPipeline.from_pretrained(model_id)
    print("✅ モデルのロード成功")
except Exception as e:
    print("❌ モデルのロード失敗:", e)

    print("❌ モデルのロード失敗:", e)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# ...

# %%
import gradio as gr
def test_func(text):
    return f"入力されたテキスト: {text}"

demo = gr.Interface(fn=test_func, inputs="text", outputs="text")
demo.launch(share=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-fb2b6653142d> in <cell line: 0>()
# ----> 1 import gradio as gr
#       2 def test_func(text):
#       3     return f"入力されたテキスト: {text}"
#       4
#       5 demo = gr.Interface(fn=test_func, inputs="text", outputs="text")
#
# ModuleNotFoundError: No module named 'gradio'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install gradio # This line installs the gradio library

import gradio as gr  # Now, you can import gradio
def test_func(text):
    return f"入力されたテキスト: {text}"

demo = gr.Interface(fn=test_func, inputs="text", outputs="text")
demo.launch(share=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 120.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline
import gradio as gr

# GPUチェック
device = "cuda" if torch.cuda.is_available() else "cpu"

# モデルロード
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id).to(device)

# 画像生成関数
def generate_image(prompt):
    image = pipe(prompt).images[0]
    return image

# Gradio UI
demo = gr.Interface(fn=generate_image, inputs="text", outputs="image")
demo.launch(share=True)

    image = pipe(prompt).images[0]
    return image
# Gradio UIdemo = gr.Interface(fn=generate_image, inputs="text", outputs="image")
demo.launch(share=True)
# Out:
#   File "<ipython-input-6-b5b591a9de41>", line 21
#     image = pipe(prompt).images[0]
#     ^
# IndentationError: unexpected indent

# %%
import torch
from diffusers import StableDiffusionPipeline
import gradio as gr

# GPUチェック
device = "cuda" if torch.cuda.is_available() else "cpu"

# モデルロード
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id).to(device)

# 画像生成関数
def generate_image(prompt):
    image = pipe(prompt).images[0]
    return image

# Gradio UI
demo = gr.Interface(fn=generate_image, inputs="text", outputs="image")
demo.launch(share=True)

# The problematic lines have been removed.
# They were causing the error because they were indented outside of any function or control flow block.
# image = pipe(prompt).images[0]
# return image
# Gradio UIdemo = gr.Interface(fn=generate_image, inputs="text", outputs="image")
# demo.launch(share=True)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d68839686926805910.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d68839686926805910.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
pip install torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...
